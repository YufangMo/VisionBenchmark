# %%
import torch

# %%
output = []
for i in range(10):
    output.append(torch.randn(32, 10))

# %%
sum(output) / 10
# Out:
# tensor([[ 0.1756,  0.2812,  0.0675, -0.3403,  0.3648, -0.4320,  0.2950,  0.0092,
#           0.1650, -0.6500],
#         [-0.3528,  0.3409, -0.0211,  0.0347, -0.1311, -0.1162, -0.0617, -0.3674,
#          -0.4115,  0.6174],
#         [ 0.1344, -0.0066, -0.1568, -0.2160, -0.6180, -0.3787,  0.0637,  0.4380,
#           0.1961, -0.6478],
#         [ 0.0237, -0.5733, -0.4635,  0.1074,  0.0250,  0.1734,  0.1242, -0.4407,
#           0.5893,  0.3618],
#         [ 0.0650,  0.1644,  0.4520, -0.1527,  0.2754,  0.4360,  0.0081, -0.4207,
#           0.0904, -0.1889],
#         [-0.1041, -0.3721,  0.6123,  0.0483, -0.0165, -0.0065, -0.3204, -0.7292,
#          -0.1828, -0.3184],
#         [ 0.1935, -0.3237, -0.0130,  0.0649, -0.4819,  0.0550, -0.0262,  0.1979,
#           0.1007, -0.3677],
#         [-0.4848,  0.0768,  0.4504,  0.2331, -0.3045,  0.0576,  0.2093, -0.2991,
#          -0.2494,  0.2159],
#         [-0.1879, -0.1129, -0.2515,  0.3097, -0.0121,  0.0981,  0.3103, -0.5954,
# ...

# %%
float(len(output))
# Out:
# 10.0
